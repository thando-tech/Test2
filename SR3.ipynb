# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = r"C:\Users\THANDOLWETHU\Closed Ended Data.csv"
df = pd.read_csv(r"C:\Users\THANDOLWETHU\Closed Ended Data.csv")
df_subset = df[columns_for_eda]

# %%
# Display the first few rows of the dataset
print("First few rows of the dataset:")
display(df.head())

# Summary statistics
print("\nSummary statistics of numeric columns:")
print(df.describe())

# %%
#1 Create a bar chart for education levels
plt.figure(figsize=(8, 6))
sns.countplot(x='EDU_LEVEL', data=df, palette='Set2')
plt.title('Distribution of Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# 2. Pie Chart for Proportions
plt.figure(figsize=(8, 8))
df['LEADER_PARTICIPATION'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Leader Participation Proportion')
plt.ylabel('')
plt.show()

# %%
# Display the available columns
print("Available columns in the dataset:")
print(df.columns)
# Out:
# Available columns in the dataset:
# Index(['DATE_TIME', 'HOUSE_PIC', 'INTERVIEW_LANG', 'EDU_RECIEVED',
#        'INFO_RECIEVING ', 'COMMUNICATION_WAY', 'LEADER_PARTICIPATION',
#        'COMMU_ORG', 'AVG_MON_SAL', 'HOUSE_HEAD', 'NO_HOUSEHOLD',
#        'CHANG_ECO_SITUA', 'ACC_STATUS', 'EDU_LEVEL', 'PARTICIPANT_JOB',
#        'SELF_BUILT_HOUSE', 'VEGES', 'FLOOD_EXP', 'YRLY_FLOOD', 'FIRE_EXP',
#        'WATER_SATISFIED', 'TOILET_TYPE', 'WATER_SOURCE'],
#       dtype='object')

# %%
# Select relevant columns for analysis
selected_columns = ['DATE_TIME', 'HOUSE_PIC', 'INTERVIEW_LANG', 'EDU_RECIEVED',
                    'INFO_RECIEVING', 'COMMUNICATION_WAY', 'LEADER_PARTICIPATION',
                    'COMMU_ORG', 'AVG_MON_SAL', 'HOUSE_HEAD', 'NO_HOUSEHOLD',
                    'CHANG_ECO_SITUA', 'ACC_STATUS', 'EDU_LEVEL', 'PARTICIPANT_JOB',
                    'SELF_BUILT_HOUSE', 'VEGES', 'FLOOD_EXP', 'YRLY_FLOOD', 'FIRE_EXP',
                    'WATER_SATISFIED', 'TOILET_TYPE', 'WATER_SOURCE']

# Keeping only the selected columns
df = df[selected_columns]

# %%
# Advanced Charts
# 4. Scatter plot of 'AVG_MON_SAL' vs 'NO_HOUSEHOLD'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='NO_HOUSEHOLD', y='AVG_MON_SAL')
plt.title('Average Monthly Salary vs Number of Households')
plt.xlabel('Number of Households')
plt.ylabel('Average Monthly Salary')
plt.show()

# %%
# Histogram for 'AVG_MON_SAL'
plt.figure(figsize=(10, 6))
sns.histplot(df['AVG_MON_SAL'], bins=20, kde=True)
plt.title('Distribution of Average Monthly Salary')
plt.xlabel('Average Monthly Salary')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\THANDOLWETHU\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
